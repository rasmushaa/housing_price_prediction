# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data restoration and encoding
# Housing data has been scraped from web and contains many null values.
# Those are tried to retrive using logical relationships between exisisting values,
# and plain reasoning.

# %%
'''
All row without price, date, and travel time information are definetally useless
'''
df = pd.read_csv('raw_housing_data.csv')
df = df[df['Paivamaara'].notna()]
df = df[df['Velaton_hinta'].notna()]
df = df[df['TravelTime'].notna()]
df = df.reset_index(drop=True)

'''
We are only interested about normal ownership houses
'''
df = df[df['Asumistyyppi'] == 'Omistus']

'''
Show fill rate of values
'''
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percentage_missing': percent_missing})
missing_value_df.sort_values('percentage_missing', inplace=True)
missing_value_df = missing_value_df.reset_index(drop=True)

display(missing_value_df)
# Out:
#                    column_name  percentage_missing
# 0                   Paivamaara            0.000000
# 1                    Longitude            0.000000
# 2                     Latitude            0.000000
# 3                     Huoneita            0.000000
# 4                  Coordinates            0.000000
# 5                Velaton_hinta            0.000000
# 6               Asuinpinta_ala            0.000000
# 7                   TravelTime            0.000000
# 8                     Kaupunki            0.000000
# 9                 Asumistyyppi            0.000000
# 10                Kaupunginosa            0.000000
# 11                      Osoite            0.000000
# 12                       Kunto            1.149058
# 13                      Kerros            1.244813
# 14                Hoitovastike            2.010852
# 15              Tontin_omistus            2.585381
# 16                  Uudiskohde            3.830195
# 17               Rakennusvuosi            3.989786
# 18               Energialuokka            5.841047
# 19              Korkein_kerros            7.468880
# 20                 Kohdenumero           13.724864
# 21                Yhtiovastike           16.501756
# 22                     Parveke           17.299713
# 23      Huoneistojen_lukumaara           18.225343
# 24             Rahoitusvastike           24.736674
# 25            Tulevat_remontit           43.919566
# 26             Tehdyt_remontit           44.111076
# 27                       Sauna           46.121928
# 28        Tontin_vuokravastike           81.998085
# 29  Vuokratontin_lunastusosuus           85.157996
# 30                       Ranta           97.957229

# %%
'''
Condominium payment should be as sum of all other ownership related payments
by definition, thus missin values may be adjusted by summing all other found fees together
'''

df['Yhtiovastike'].fillna(df['Hoitovastike'].fillna(0) + 
                          df['Rahoitusvastike'].fillna(0) + 
                          df['Tontin_vuokravastike'].fillna(0), inplace = True)

df.loc[df['Yhtiovastike'] < 10, 'Yhtiovastike'] = 0

percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percentage_missing': percent_missing})
missing_value_df.sort_values('percentage_missing', inplace=True)
missing_value_df = missing_value_df.reset_index(drop=True)

display(missing_value_df)
# Out:
#                    column_name  percentage_missing
# 0                   Paivamaara            0.000000
# 1                    Longitude            0.000000
# 2                     Latitude            0.000000
# 3                     Huoneita            0.000000
# 4                  Coordinates            0.000000
# 5                 Yhtiovastike            0.000000
# 6                Velaton_hinta            0.000000
# 7               Asuinpinta_ala            0.000000
# 8                   TravelTime            0.000000
# 9                     Kaupunki            0.000000
# 10                Asumistyyppi            0.000000
# 11                Kaupunginosa            0.000000
# 12                      Osoite            0.000000
# 13                       Kunto            1.149058
# 14                      Kerros            1.244813
# 15                Hoitovastike            2.010852
# 16              Tontin_omistus            2.585381
# 17                  Uudiskohde            3.830195
# 18               Rakennusvuosi            3.989786
# 19               Energialuokka            5.841047
# 20              Korkein_kerros            7.468880
# 21                 Kohdenumero           13.724864
# 22                     Parveke           17.299713
# 23      Huoneistojen_lukumaara           18.225343
# 24             Rahoitusvastike           24.736674
# 25            Tulevat_remontit           43.919566
# 26             Tehdyt_remontit           44.111076
# 27                       Sauna           46.121928
# 28        Tontin_vuokravastike           81.998085
# 29  Vuokratontin_lunastusosuus           85.157996
# 30                       Ranta           97.957229

# %%
'''
Similar idea for running costs
'''

df['Hoitovastike'].fillna(df['Yhtiovastike'].fillna(0) - 
                          df['Rahoitusvastike'].fillna(0) - 
                          df['Tontin_vuokravastike'].fillna(0), inplace = True)

df.loc[df['Hoitovastike'] < 10, 'Hoitovastike'] = 0

percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percentage_missing': percent_missing})
missing_value_df.sort_values('percentage_missing', inplace=True)
missing_value_df = missing_value_df.reset_index(drop=True)

display(missing_value_df)
# Out:
#                    column_name  percentage_missing
# 0                   Paivamaara            0.000000
# 1                    Longitude            0.000000
# 2                     Latitude            0.000000
# 3                     Huoneita            0.000000
# 4                  Coordinates            0.000000
# 5                 Hoitovastike            0.000000
# 6                 Yhtiovastike            0.000000
# 7                Velaton_hinta            0.000000
# 8               Asuinpinta_ala            0.000000
# 9                   TravelTime            0.000000
# 10                Asumistyyppi            0.000000
# 11                    Kaupunki            0.000000
# 12                      Osoite            0.000000
# 13                Kaupunginosa            0.000000
# 14                       Kunto            1.149058
# 15                      Kerros            1.244813
# 16              Tontin_omistus            2.585381
# 17                  Uudiskohde            3.830195
# 18               Rakennusvuosi            3.989786
# 19               Energialuokka            5.841047
# 20              Korkein_kerros            7.468880
# 21                 Kohdenumero           13.724864
# 22                     Parveke           17.299713
# 23      Huoneistojen_lukumaara           18.225343
# 24             Rahoitusvastike           24.736674
# 25            Tulevat_remontit           43.919566
# 26             Tehdyt_remontit           44.111076
# 27                       Sauna           46.121928
# 28        Tontin_vuokravastike           81.998085
# 29  Vuokratontin_lunastusosuus           85.157996
# 30                       Ranta           97.957229

# %%
'''
And for financial costs
'''

df['Rahoitusvastike'].fillna(df['Yhtiovastike'].fillna(0) - 
                          df['Hoitovastike'].fillna(0) - 
                          df['Tontin_vuokravastike'].fillna(0), inplace = True)

df.loc[df['Rahoitusvastike'] < 10, 'Rahoitusvastike'] = 0

percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percentage_missing': percent_missing})
missing_value_df.sort_values('percentage_missing', inplace=True)
missing_value_df = missing_value_df.reset_index(drop=True)

display(missing_value_df)
# Out:
#                    column_name  percentage_missing
# 0                   Paivamaara            0.000000
# 1                    Longitude            0.000000
# 2                     Latitude            0.000000
# 3                     Huoneita            0.000000
# 4                  Coordinates            0.000000
# 5              Rahoitusvastike            0.000000
# 6                 Hoitovastike            0.000000
# 7                 Yhtiovastike            0.000000
# 8                Velaton_hinta            0.000000
# 9               Asuinpinta_ala            0.000000
# 10                  TravelTime            0.000000
# 11                    Kaupunki            0.000000
# 12                Asumistyyppi            0.000000
# 13                      Osoite            0.000000
# 14                Kaupunginosa            0.000000
# 15                       Kunto            1.149058
# 16                      Kerros            1.244813
# 17              Tontin_omistus            2.585381
# 18                  Uudiskohde            3.830195
# 19               Rakennusvuosi            3.989786
# 20               Energialuokka            5.841047
# 21              Korkein_kerros            7.468880
# 22                 Kohdenumero           13.724864
# 23                     Parveke           17.299713
# 24      Huoneistojen_lukumaara           18.225343
# 25            Tulevat_remontit           43.919566
# 26             Tehdyt_remontit           44.111076
# 27                       Sauna           46.121928
# 28        Tontin_vuokravastike           81.998085
# 29  Vuokratontin_lunastusosuus           85.157996
# 30                       Ranta           97.957229

# %%
'''
And for land rent fee
'''

df['Tontin_vuokravastike'].fillna(df['Yhtiovastike'].fillna(0) - 
                          df['Hoitovastike'].fillna(0) - 
                          df['Rahoitusvastike'].fillna(0), inplace = True)

def transformer(row):
    if row['Tontin_omistus'] != np.nan:
        if row['Tontin_omistus'] == 'Oma':
            return 0.0
        else:
            return row['Tontin_vuokravastike']
    else:
       return row['Tontin_vuokravastike']
    
df['Tontin_vuokravastike'] = df.apply(lambda x: transformer(x), axis=1)

df.loc[df['Tontin_vuokravastike'] < 10, 'Tontin_vuokravastike'] = 0


percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percentage_missing': percent_missing})
missing_value_df.sort_values('percentage_missing', inplace=True)
missing_value_df = missing_value_df.reset_index(drop=True)

display(missing_value_df)
# Out:
#                    column_name  percentage_missing
# 0                   Paivamaara            0.000000
# 1                    Longitude            0.000000
# 2                     Latitude            0.000000
# 3                     Huoneita            0.000000
# 4                  Coordinates            0.000000
# 5         Tontin_vuokravastike            0.000000
# 6              Rahoitusvastike            0.000000
# 7                 Hoitovastike            0.000000
# 8                 Yhtiovastike            0.000000
# 9                Velaton_hinta            0.000000
# 10              Asuinpinta_ala            0.000000
# 11                  TravelTime            0.000000
# 12                    Kaupunki            0.000000
# 13                Asumistyyppi            0.000000
# 14                      Osoite            0.000000
# 15                Kaupunginosa            0.000000
# 16                       Kunto            1.149058
# 17                      Kerros            1.244813
# 18              Tontin_omistus            2.585381
# 19                  Uudiskohde            3.830195
# 20               Rakennusvuosi            3.989786
# 21               Energialuokka            5.841047
# 22              Korkein_kerros            7.468880
# 23                 Kohdenumero           13.724864
# 24                     Parveke           17.299713
# 25      Huoneistojen_lukumaara           18.225343
# 26            Tulevat_remontit           43.919566
# 27             Tehdyt_remontit           44.111076
# 28                       Sauna           46.121928
# 29  Vuokratontin_lunastusosuus           85.157996
# 30                       Ranta           97.957229

# %%
'''
If apartemt has a land rent fee of 0€, then it's located on its own land
Or if it's possible to byu the land, then its on rent land

Encoding:
3 'Oma' - own land
2 'Valinnainen vuokratontti' - possibility to buy your part of the land
1 'Vuokralla' - rental land
'''
print(f'Unique values of landownership: {df.Tontin_omistus.unique()}')

df.loc[df['Tontin_omistus'] == 'Oma', 'Tontin_omistus'] = 3
df.loc[df['Tontin_omistus'] == 'Valinnainen vuokratontti', 'Tontin_omistus'] = 2
df.loc[df['Tontin_omistus'] == 'Vuokralla', 'Tontin_omistus'] = 1

def transformer(row):
    if row['Tontin_omistus'] == np.nan:
        if row['Tontin_vuokravastike'] == 0:
            return 3
        elif row['Vuokratontin_lunastusosuus'] != 0:
            return 2
        else:
            return np.nan
    else:
       return row['Tontin_omistus']
    
df['Tontin_omistus'] = df.apply(lambda x: transformer(x), axis=1)


'''
If land ownership is not 2 'Valinnainen vuokratontti', then land buyng price is 0
'''
def transformer(row):
    if row['Tontin_omistus'] == 2:
        return row['Vuokratontin_lunastusosuus']
    else:
       return 0
    
df['Vuokratontin_lunastusosuus'] = df.apply(lambda x: transformer(x), axis=1)

percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percentage_missing': percent_missing})
missing_value_df.sort_values('percentage_missing', inplace=True)
missing_value_df = missing_value_df.reset_index(drop=True)

display(missing_value_df)

print(f'Unique values of landownership: {df.Tontin_omistus.unique()}')
# Out:
# Unique values of landownership: ['Oma' 'Vuokralla' nan 'Valinnainen vuokratontti']
#                    column_name  percentage_missing
# 0                   Paivamaara            0.000000
# 1                    Longitude            0.000000
# 2                     Latitude            0.000000
# 3                     Huoneita            0.000000
# 4                  Coordinates            0.000000
# 5         Tontin_vuokravastike            0.000000
# 6              Rahoitusvastike            0.000000
# 7                 Hoitovastike            0.000000
# 8                 Yhtiovastike            0.000000
# 9                Velaton_hinta            0.000000
# 10              Asuinpinta_ala            0.000000
# 11                  TravelTime            0.000000
# 12                    Kaupunki            0.000000
# 13                Asumistyyppi            0.000000
# 14                      Osoite            0.000000
# 15                Kaupunginosa            0.000000
# 16                       Kunto            1.149058
# 17                      Kerros            1.244813
# 18  Vuokratontin_lunastusosuus            1.563996
# 19              Tontin_omistus            2.585381
# 20                  Uudiskohde            3.830195
# 21               Rakennusvuosi            3.989786
# 22               Energialuokka            5.841047
# 23              Korkein_kerros            7.468880
# 24                 Kohdenumero           13.724864
# 25                     Parveke           17.299713
# 26      Huoneistojen_lukumaara           18.225343
# 27            Tulevat_remontit           43.919566
# 28             Tehdyt_remontit           44.111076
# 29                       Sauna           46.121928
# 30                       Ranta           97.957229
# Unique values of landownership: [ 3.  1. nan  2.]

# %%
'''
If the building year is larger than the date,
then its a new building.
Also if the condition says its new, then building has just finished.

Encoding:
1 'Kylla' - its a brand new building
0 'Ei' - its NOT a brand new building

1 'Välttävä' - in bad shape
2 'Tyydyttävä' - beareble shape
3 'Hyvä' - ok
4 'Erinomainen' - excellent
5 'Uusi' - new
'''
print(f'Unique values of new building flag: {df.Uudiskohde.unique()}')
print(f'Unique values of condition: {df.Kunto.unique()}')

df.loc[df['Uudiskohde'] == 'Kyllä', 'Uudiskohde'] = 1
df.loc[df['Uudiskohde'] == 'Ei', 'Uudiskohde'] = 0

def transformer(row):
    if row['Rakennusvuosi'] > float(row['Paivamaara'][:4]):
        return 1
    elif row['Kunto'] == 'Uusi':
        return 1
    else:
       return row['Uudiskohde']
    
df['Uudiskohde'] = df.apply(lambda x: transformer(x), axis=1)


df.loc[df['Kunto'] == 'Välttävä', 'Kunto'] = 1
df.loc[df['Kunto'] == 'Tyydyttävä', 'Kunto'] = 2
df.loc[df['Kunto'] == 'Hyvä', 'Kunto'] = 3
df.loc[df['Kunto'] == 'Erinomainen', 'Kunto'] = 4
df.loc[df['Kunto'] == 'Uusi', 'Kunto'] = 5


percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percentage_missing': percent_missing})
missing_value_df.sort_values('percentage_missing', inplace=True)
missing_value_df = missing_value_df.reset_index(drop=True)

display(missing_value_df)

print(f'Unique values of new building flag: {df.Uudiskohde.unique()}')
print(f'Unique values of condition: {df.Kunto.unique()}')
# Out:
# Unique values of new building flag: ['Ei' 'Kyllä' nan]
# Unique values of condition: ['Hyvä' 'Tyydyttävä' 'Uusi' 'Erinomainen' nan 'Välttävä']
#                    column_name  percentage_missing
# 0                   Paivamaara            0.000000
# 1                    Longitude            0.000000
# 2                     Latitude            0.000000
# 3                     Huoneita            0.000000
# 4                  Coordinates            0.000000
# 5         Tontin_vuokravastike            0.000000
# 6              Rahoitusvastike            0.000000
# 7                 Hoitovastike            0.000000
# 8                 Yhtiovastike            0.000000
# 9                Velaton_hinta            0.000000
# 10              Asuinpinta_ala            0.000000
# 11                  TravelTime            0.000000
# 12                    Kaupunki            0.000000
# 13                Asumistyyppi            0.000000
# 14                      Osoite            0.000000
# 15                Kaupunginosa            0.000000
# 16                       Kunto            1.149058
# 17                      Kerros            1.244813
# 18  Vuokratontin_lunastusosuus            1.563996
# 19              Tontin_omistus            2.585381
# 20                  Uudiskohde            3.830195
# 21               Rakennusvuosi            3.989786
# 22               Energialuokka            5.841047
# 23              Korkein_kerros            7.468880
# 24                 Kohdenumero           13.724864
# 25                     Parveke           17.299713
# 26      Huoneistojen_lukumaara           18.225343
# 27            Tulevat_remontit           43.919566
# 28             Tehdyt_remontit           44.111076
# 29                       Sauna           46.121928
# 30                       Ranta           97.957229
# Unique values of new building flag: [ 0.  1. nan]
# Unique values of condition: [3 2 5 4 nan 1]

# %%
'''
Balcony, sauna and beach are goof additions,
and I assume that if those would be included. it woudl have been stated.
Thus Nans and nopes are both 0.

Encoding:
1 'Kylla' - incuded
0 'Ei' - not included
'''

print(f'Unique values of sauna flag: {df.Sauna.unique()}')
print(f'Unique values of balcony: {df.Parveke.unique()}')
print(f'Unique values of beach: {df.Ranta.unique()}')


df.loc[df['Parveke'] == 'Kyllä', 'Parveke'] = 1
df.loc[df['Parveke'] != 1, 'Parveke'] = 0

df.loc[df['Sauna'] == 'Kyllä', 'Sauna'] = 1
df.loc[df['Sauna'] != 1, 'Sauna'] = 0

df['Ranta'].fillna(0, inplace=True)
df.loc[df['Ranta'] == 'Ei rantaa', 'Ranta'] = 0
df.loc[df['Ranta'] != 0, 'Ranta'] = 1

df.loc[df['Kerros'] != df['Korkein_kerros'], 'Korkein_kerros'] = 0
df.loc[df['Korkein_kerros'] != 0, 'Korkein_kerros'] = 1

df.loc[df['Rakennusvuosi'] < 1700, 'Rakennusvuosi'] = np.nan


percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percentage_missing': percent_missing})
missing_value_df.sort_values('percentage_missing', inplace=True)
missing_value_df = missing_value_df.reset_index(drop=True)

display(missing_value_df)

print(f'Unique values of sauna flag: {df.Sauna.unique()}')
print(f'Unique values of balcony: {df.Parveke.unique()}')
print(f'Unique values of beach: {df.Ranta.unique()}')
# Out:
# Unique values of sauna flag: ['Kyllä' nan 'Ei']
# Unique values of balcony: ['Kyllä' nan 'Ei']
# Unique values of beach: [nan 'Ei rantaa' 'Muu ranta' 'Rantaoikeus']
#                    column_name  percentage_missing
# 0                   Paivamaara            0.000000
# 1                    Longitude            0.000000
# 2                     Latitude            0.000000
# 3                        Ranta            0.000000
# 4                        Sauna            0.000000
# 5                      Parveke            0.000000
# 6               Korkein_kerros            0.000000
# 7                     Huoneita            0.000000
# 8                  Coordinates            0.000000
# 9         Tontin_vuokravastike            0.000000
# 10             Rahoitusvastike            0.000000
# 11                Hoitovastike            0.000000
# 12              Asuinpinta_ala            0.000000
# 13               Velaton_hinta            0.000000
# 14                    Kaupunki            0.000000
# 15                Yhtiovastike            0.000000
# 16                      Osoite            0.000000
# 17                Asumistyyppi            0.000000
# 18                Kaupunginosa            0.000000
# 19                  TravelTime            0.000000
# 20                       Kunto            1.149058
# 21                      Kerros            1.244813
# 22  Vuokratontin_lunastusosuus            1.563996
# 23              Tontin_omistus            2.585381
# 24                  Uudiskohde            3.830195
# 25               Rakennusvuosi            4.021704
# 26               Energialuokka            5.841047
# 27                 Kohdenumero           13.724864
# 28      Huoneistojen_lukumaara           18.225343
# 29            Tulevat_remontit           43.919566
# 30             Tehdyt_remontit           44.111076
# Unique values of sauna flag: [1 0]
# Unique values of balcony: [1 0]
# Unique values of beach: [0 1]

# %%
'''
It's hard to process string information of energy level,
but it seems that if there is only 6 characters,
its in form of A2022 or A/2022.
This should give at least some information.

Encoding:
1 'A' - the best
2 'B' - second best
...
...
..
'''

print(f'Unique values of energy class: {df.Energialuokka.unique()}')


def transformer(row):
    if row['Energialuokka'] is not np.nan and len(row['Energialuokka']) <= 6:
        return row['Energialuokka'][0]
    else:
       return np.nan
    
df['Energialuokka'] = df.apply(lambda x: transformer(x), axis=1)

df['Energialuokka'] = df['Energialuokka'].apply(lambda x: ord(x.lower()) - 96 if x is not np.nan else np.nan)

df.loc[df['Energialuokka'] < 0, 'Energialuokka'] = np.nan


percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percentage_missing': percent_missing})
missing_value_df.sort_values('percentage_missing', inplace=True)
missing_value_df = missing_value_df.reset_index(drop=True)

display(missing_value_df)

print(f'Unique values of energy class: {df.Energialuokka.unique()}')
# Out:
# Unique values of energy class: ['Energialuokka: E2007' 'E2018' 'G2013'
#  'Energialuokka: F2013, Energiatodistuksen voimassaoloaika: 21.02.2026'
#  'D2007' 'A2018' 'E2013' 'F2018' 'C2013' 'B2018'
#  'Energialuokka: G2013, Energiatodistuksen voimassaoloaika: 14.01.2025'
#  'F/2013' 'F2013' 'E2007' 'G2013 Viimeinen voimassaolopäivä 4.11.2024.'
#  'F/2007' 'C2007' 'E2007 Viimeinen voimassaolo 30.1.2023.' 'G/2007'
#  'F2007'
#  'Energialuokka: D2018, Energiatodistuksen voimassaoloaika: 28.12.2032'
#  'E/2013' 'G2013 Voimassa 4.9.2024' 'D2007 Voimassa 19.5.2023 asti' 'A'
#  'Energialuokka: E2013, Energiatodistuksen voimassaoloaika: 22.03.2025'
#  'D2018' 'C2018'

#  'Energialuokka: F2013, Energiatodistuksen voimassaoloaika: 23.01.2025'
#  'B2018 Voimassa 21.12.2030 saakka' 'B2018 Voimassa 30.1.2030 saakka'
#  'Energialuokka: C2013'
#  'Kohteelle ei lain mukaan tarvita energiatodistusta.'
#  'Energialuokka: C2007, Lisätiedot: Kohteesta on energiatodistus. Energialuokka: C2007 04.04.2026'
#  'E2018 e-luku: 175. Energiatodistus voimassa 27.4.2029 asti.'
#  'D2013 (voim. 9.11.2025 asti)'
#  'E2018 E-luku 166, energiatodistus on voimassa 23.12.2029 saakka.'
#  'F2013 Voimassa 29.9.2024' 'A2007' 'C' 'G'
#  'F2007 Erillinen energiatodistus, joka on voimassa 10 vuotta.'
#  'Energialuokka: C2013, Energiatodistuksen voimassaoloaika: 07.12.2028'
#  'E2013 voimassa 17.4.2023' 'B/2018' 'Energialuokka: D2013'
#  'Ei lain edellyttämää energiatodistusta'
#  'Energialuokka: C2013, Energiatodistuksen voimassaoloaika: 26.06.2028'
#  'D 2007' 'C2013 E-Luku 130'
#  'Energialuokka: D2018, Energiatodistuksen voimassaoloaika: 21.02.2030'
#  'Energialuokka: D2013, Energiatodistuksen voimassaoloaika: 28.02.2023'
#  'E2018 voimassa 27.01.2029 asti' 'B2018 18.3.2020-18.3.2030'
#  'E2007 Energiatodistus vanhentunut 23.4.2022.'
#  'C2013 viimeinen voimassaolopäivä 13.12.2027'
#  'Energialuokka: B2018, Energiatodistuksen voimassaoloaika: 11.10.2029'
#  'G2013 E-luku 248, viimeinen voimassaolopäivä 20.7.2024' 'F' 'E/2007'
#  'E2018 22.11.2020-22.11.2030'
#  'Lisätiedot: Yhtiön energiatodistuksen voimassaolo päättynyt 27.1.2023'
#  'B2018 Voimassa 2.10.2030 saakka. Kts. energiatodistus.'
#  'D2007 Energiatodistus ei ole enää voimassa. Vanhentunut 31.12.2022'
#  'E, 2007' 'A, 2018'
#  'Energialuokka: F2013, Energiatodistuksen voimassaoloaika: 26.01.2025'
#  'Energialuokka: D2007, Energiatodistuksen voimassaoloaika: 30.05.2023'
#  'B2007 Energiatodistus on annettu 27.5.2013.'
#  'Energialuokka: C2013, Energiatodistuksen voimassaoloaika: 16.02.2017'
#  'Energialuokka: D'
#  'Energialuokka: F2018, Energiatodistuksen voimassaoloaika: 19.03.2028'
#  'F2013 Voimassa 15.12.2027 asti.' 'E/2014'
#  'Energialuokka: E2018, Energiatodistuksen voimassaoloaika: 17.01.2033'
#  'E2007 Viimeinen voimassaolopäivä 18.5.2023.'
#  'Energialuokka: F2013, Energiatodistuksen voimassaoloaika: 29.06.2025'
#  'Energialuokka: G2013, Energiatodistuksen voimassaoloaika: 08.03.2025'
#  'F2013 Voimassa 1.1.2025 asti'
#  'F2013 Laatimispäivä 13.11.2014, voimassa 13.11.2024 saakka.'
#  'C2007 Energiatodistuksen viimeinen voimassaolopäivä on 23.5.2023'
#  'Energialuokka: D2007, Energiatodistuksen voimassaoloaika: 16.05.2023'
#  'F2013 Energiatodistus laadittu 23.8.2014.' 'Ei energiatodistusta'
#  'F2013 E-luku 234. Energiatodistus voimassa 14.01.2025 asti.'
#  'D2018 Voimassa 21.4.2032.'
#  'Energialuokka: C2013, Energiatodistuksen voimassaoloaika: 16.04.2025'
#  'F2013 voimassa 23.7.2014-23.7.2024, E-luku 217'
#  'Taloyhtiön rakennukset ovat kaavassa suojeltuja ja ovat  tästä syystä lain mukaan vapautettuja velvollisuudesta hankkia rakennuksen energiatodistus.'
#  'B2018 Viimeinen voimassaolopäivä on 26.8.2030' 'B2018 E-luku 76.'
#  'Energialuokka: E2007, Energiatodistuksen voimassaoloaika: 30.05.2023'
#  'Energialuokka: G2013'
#  'Energialuokka: B2007, Lisätiedot: Yhtiön energiatodistus on voimassa vielä vuoden 2023.'
#  'C2013 Energiatodistus on voimassa 17.5.2029 saakka.'
#  'Energialuokka: C2013, Energiatodistuksen voimassaoloaika: 13.02.2029'
#  'D2007 Energiatodistus annettu 31.5.2013.'
#  'Energialuokka: C2013, Energiatodistuksen voimassaoloaika: 17.10.2026'
#  'E2007 Taloyhtiön energiatodistus (vuodelta 2013) pohjaa vanhaan kulutukseen perustavaan laskentaan.'
#  'G / 2013' 'F2013 (Et-luku 231)' 'G 2013' 'G2013 Voimassa 3.6.2024 asti.'
#  'E2007 Energiatodistuksen antamispäivä 31.5.2013.'
#  'F2013 Energiatodistus voimassa 02.03.2025 saakka.'
#  'Energialuokka: F2013, Energiatodistuksen voimassaoloaika: 17.08.2024'
#  'A2018 Todistuksen laatimispäivä 25.4.2022, viimeinen voimassaolopäivä 25.4.2032.'
#  'kohteelle ei lain mukaan tarvita energiatodistusta'
#  'F2013 Energialuokka: F2013, Energiatodistuksen voimassaoloaika: 06.11.2024, Lisätiedot: E-luku 230'
#  'B2018 voimassa 14.8.2029'
#  'Energialuokka: E2013, Energiatodistuksen voimassaoloaika: 07.10.2024'
#  'E2018 Liiketilojen energialuokka C2018.' 'E2007 Vanhentunut 31.12.2022'
#  'F2007 Energia todistuksen viimeisin voimassaolopäivä 3.2.2023'
#  'Yhtiöllä rakennuslupamenettelyn yhteydessä tehty energiatodistus, joka perustuu laskennalliseen kulutukseen (Energiatodistus D2007)'
#  'Energialuokka: E2013, Energiatodistuksen voimassaoloaika: 19.05.2024'
#  'Energialuokka: B2018, Energiatodistuksen voimassaoloaika: 07.12.2030'
#  'Energialuokka: F2013, Energiatodistuksen voimassaoloaika: 18.09.2024'
#  'C2013 Perustuu laskennalliseen kokonaisenergiankulutukseen.\nKoneellinen tulo- ja poistoilmanvaihtojärjestelmä.'
#  'E2013 Energiatodistuksen viimeinen voimassaolopäivä 5.3.2025'
#  'Energialuokka: D2007, Energiatodistuksen voimassaoloaika: 31.12.2022'
#  'G2013 Energiatodistuksen viimeinen voimassaolopäivä: 15.01.2025'
#  'Energialuokka: E2013, Energiatodistuksen voimassaoloaika: 03.06.2024'
#  'C2013 voimassaolopäivä 28.8.2029' 'Energialuokka: F2013'
#  'C2013 E-luku: 116.' 'F2013 E--liku: 230'
#  'E2007 Todistuksen antamispäivä 26.5.2013\nViimeinen voimassaolopäivä 25.5.2023'
#  'F2013 Energiatodistus laadittu 27.6.2013 ja voimassa 26.6.2023 saakka.'
#  'E2007 Todistuksen antamispäivä 18.4.2013\nViimeinen voimassaolopäivä 17.4.2023'

#  'Energialuokka: F2013, Energiatodistuksen voimassaoloaika: 09.05.2024'
#  'C2013 Todistus on laadittu 16.4.2014.'
#  'Energialuokka: G2007, Energiatodistuksen voimassaoloaika: 04.12.2024'
#  'Energialuokka: B2018, Energiatodistuksen voimassaoloaika: 12.04.2028'
#  'A2018 Kts. energiatodistus.' 'Laki ei edellytä energiatodistusta'
#  'B2018 Voimassa 10.9.2030 asti'
#  'D2018 Energiatodistuspalvelu Marttila, Aki Marttila 22.9.2020, voimassa 22.9.2030 asti.'
#  'Energialuokka: B2007, Energiatodistuksen voimassaoloaika: 01.01.2023, Lisätiedot: Tarkkaa voimassaolopäivää ei tiedossa, isännöitsijäntodistuksessa mainittu vain vuosi 2023.'
#  'E 2007' 'F2013 energiatodistus laadittu 15.1.2015'
#  'G2013 Viimeinen voimassaolopäivä 20.7.2024 saakka, E-luku 251'
#  'C Laatimispäivä 16.12.2016' 'C2007 Voimassa 19.05.2023 asti.' 'D, 2018'
#  'D2018 Voimassa 23.11.2030'
#  'G2013 Energiatodistus voimassa 15.02.2025 asti'
#  'Energialuokka: F2013, Energiatodistuksen voimassaoloaika: 06.11.2024, Lisätiedot: E-luku 230'
#  'D2007 Viimeinen voimassaolopäivä 31.12.2022' 'F2013 Et-luku 212'
#  'Voimassaolevaa energiatodistusta ei ole. Se laaditaan nyt tulevan peruskorjaushankkeen suunnittelun yhteydessä.'
#  'E2013 Antamispäivä 22.02.2013, voimassa 22.02.2023'
#  'Ei lain vaatimaa energiatodistusta']
#                    column_name  percentage_missing
# 0                   Paivamaara            0.000000
# 1                    Longitude            0.000000
# 2                     Latitude            0.000000
# 3                        Ranta            0.000000
# 4                        Sauna            0.000000
# 5                      Parveke            0.000000
# 6               Korkein_kerros            0.000000
# 7                     Huoneita            0.000000
# 8                  Coordinates            0.000000
# 9         Tontin_vuokravastike            0.000000
# 10             Rahoitusvastike            0.000000
# 11                Hoitovastike            0.000000
# 12              Asuinpinta_ala            0.000000
# 13               Velaton_hinta            0.000000
# 14                    Kaupunki            0.000000
# 15                Yhtiovastike            0.000000
# 16                      Osoite            0.000000
# 17                Asumistyyppi            0.000000
# 18                Kaupunginosa            0.000000
# 19                  TravelTime            0.000000
# 20                       Kunto            1.149058
# 21                      Kerros            1.244813
# 22  Vuokratontin_lunastusosuus            1.563996
# 23              Tontin_omistus            2.585381
# 24                  Uudiskohde            3.830195
# 25               Rakennusvuosi            4.021704
# 26                 Kohdenumero           13.724864
# 27      Huoneistojen_lukumaara           18.225343
# 28               Energialuokka           33.163102
# 29            Tulevat_remontit           43.919566
# 30             Tehdyt_remontit           44.111076
# Unique values of energy class: [nan  5.  7.  4.  1.  6.  3.  2.]

# %%
'''
If renovation info contains LVI (very expensive bluming and electricity renovation)
flag it.

Encoding:
1 contains LVI
0 does not contain LVI

'''

def transformer(row):
    if row['Tulevat_remontit'] is not np.nan:
        if 'LVI' in row['Tulevat_remontit'] or 'lvi' in row['Tulevat_remontit']:
            return 1
        else:
            return 0
    else:
       return 0
    
df['Tulevat_remontit'] = df.apply(lambda x: transformer(x), axis=1)


def transformer(row):
    if row['Tehdyt_remontit'] is not np.nan:
        if 'LVI' in row['Tehdyt_remontit'] or 'lvi' in row['Tehdyt_remontit']:
            return 1
        else:
            return 0
    else:
       return 0
    
df['Tehdyt_remontit'] = df.apply(lambda x: transformer(x), axis=1)


percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percentage_missing': percent_missing})
missing_value_df.sort_values('percentage_missing', inplace=True)
missing_value_df = missing_value_df.reset_index(drop=True)

display(missing_value_df)

print(f'Unique values of upcoming renovations: {df.Tulevat_remontit.unique()}')
print(f'Unique values of past renovations: {df.Tehdyt_remontit.unique()}')
# Out:
#                    column_name  percentage_missing
# 0                   Paivamaara            0.000000
# 1                    Longitude            0.000000
# 2                     Latitude            0.000000
# 3              Tehdyt_remontit            0.000000
# 4             Tulevat_remontit            0.000000
# 5                        Ranta            0.000000
# 6                        Sauna            0.000000
# 7                      Parveke            0.000000
# 8               Korkein_kerros            0.000000
# 9                     Huoneita            0.000000
# 10                 Coordinates            0.000000
# 11        Tontin_vuokravastike            0.000000
# 12             Rahoitusvastike            0.000000
# 13              Asuinpinta_ala            0.000000
# 14                Yhtiovastike            0.000000
# 15                    Kaupunki            0.000000
# 16                Kaupunginosa            0.000000
# 17                      Osoite            0.000000
# 18                Hoitovastike            0.000000
# 19                Asumistyyppi            0.000000
# 20                  TravelTime            0.000000
# 21               Velaton_hinta            0.000000
# 22                       Kunto            1.149058
# 23                      Kerros            1.244813
# 24  Vuokratontin_lunastusosuus            1.563996
# 25              Tontin_omistus            2.585381
# 26                  Uudiskohde            3.830195
# 27               Rakennusvuosi            4.021704
# 28                 Kohdenumero           13.724864
# 29      Huoneistojen_lukumaara           18.225343
# 30               Energialuokka           33.163102
# Unique values of upcoming renovations: [1 0]
# Unique values of past renovations: [1 0]

# %%
'''
Encoding:
1 Vantaa
2 Espoo
3 Helsinki

'''

print(f'Unique values of city: {df.Kaupunki.unique()}')

df.loc[df['Kaupunki'] == 'Vantaa', 'Kaupunki'] = 1
df.loc[df['Kaupunki'] == 'Espoo', 'Kaupunki'] = 2
df.loc[df['Kaupunki'] == 'ESPOO', 'Kaupunki'] = 2
df.loc[df['Kaupunki'] == 'Helsinki', 'Kaupunki'] = 3
df.loc[df['Kaupunki'] == 'HELSINKI', 'Kaupunki'] = 3

print(f'Unique values of city: {df.Kaupunki.unique()}')
# Out:
# Unique values of city: ['Espoo' 'Helsinki' 'Vantaa' 'ESPOO']
# Unique values of city: [2 3 1]

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

'''
Encoding:
Districts are dummified randomly
'''

print(f'Unique values of district: {df.Kaupunginosa.unique()}')

df['Kaupunginosa'] = label_encoder.fit_transform(df['Kaupunginosa'])

print(f'Unique values of district: {df.Kaupunginosa.unique()}')
# Out:
# Unique values of district: ['Leppävaara' 'Herttoniemi' 'Ullanlinna' 'Sörnäinen' 'Tapiola' 'Kallio'
#  'Pakila' 'Tikkurila' 'Vallila' 'Pitäjänmäki' 'Myyrmäki' 'Pasila'
#  'Hakunila' 'Espoon keskus' 'Vermonniitty' 'Kera' 'Kilo' 'Viherlaakso'
#  'Kannelmäki' 'Tali' 'Munkkivuori' 'Pohjois-Haaga' 'Alppila' 'Järvenperä'
#  'Vapaala' 'Saunalahti' 'Arabianranta' 'Kamppi' 'Hermanni'
#  'Viikinranta/Vanhankaupunginkoski' 'Myllypuro' 'Pakkala' 'Kuitinmäki'
#  'Haukilahti' 'Kartanonkoski' 'Herttoniemenranta' 'Taka-Töölö' 'Puotila'
#  'Etelä-Haaga' 'Viikki' 'Tapaninkylä' 'Lauttasaari' 'Olari' 'Pisa'
#  'Viikinmäki' 'Etu-Töölö' 'Pohjois-Tapiola' 'Ylästö' 'Niittykumpu' 'Malmi'
#  'Harju' 'Aurinkolahti' 'Maunula' 'Matinkylä' 'Laajasalo' 'Matinkyä'
#  'Simonmetsä' 'Roihuvuori' 'Länsi-Pasila' 'Punavuori' 'Pukinmäki'
#  'Kumpula' 'Soukka' 'Kaivoksela' 'Kruunuvuorenranta' 'Meilahti' 'Yliskylä'
#  'Tillinmäki' 'Tontunmäki' 'Pajamäki' 'Vuosaari'
#  'Puolarmetsä Friisilä Olari' 'Tapaninvainio' 'Munkkisaari' 'Haaga'
#  'Tapanila' 'Leinelä' 'Konepaja' 'Munkkiniemi' 'Töölö'
#  'Leppävaara / Vermonniitty' 'Alppiharju' 'Kalasatama' 'Kivistö'
#  'Hermanninranta' 'Kauklahti' 'Laurinlahti' 'Konala' 'Ruskeasuo' 'Henttaa'
#  'Kulosaari' 'Kruununhaka' 'Asola' 'Pähkinärinne' 'Tammisto'
#  'Kallio/Harju' 'Lippajärvi' 'Kavallinmäki' 'Käpylä' 'Rajatorppa'
#  'Alppiharju (Harju)' 'Itäkeskus' 'Pikku Huopalahti' 'Oulunkylä'
#  'Painiitty' 'Viertola' 'Aviapolis' 'Hietalahti' 'Suurpelto' 'Kaarela'
#  'Koskela' 'Hiekkaharju' 'Nihtisilta' 'Simonkylä' 'Espoonlahti'
#  'Pihlajisto' 'Nöykkiö' 'Mellunkylä' 'Martinlaakso' 'Vallikallio'
#  'Louhela' 'Matari' 'Finnoo' 'Hernesaari' 'Westend' 'Korso Kulomäki'
#  'Tuomarila' 'Siltamäki' 'Pirkkola' 'Tuomarila/Kulovalkea' 'Veräjälaakso'
#  'Lippajärvi / Lähderanta' 'Puotinharju' 'Nikinmäki' 'Vanhakaupunki'
#  'Hakaniemi' 'Kalajärvi' 'Latokartano' 'Sepänmäki' 'Harmaalaakso'
#  'Vantaanlaakso' 'Torkkelinmäki / Kallio' 'Merihaka' 'Kuninkaantammi'
#  'Malminkartano' 'Vartiokylä' 'Lassila' 'Länsi-Herttoniemi' 'Iivisniemi'
#  'Talinranta' 'Pohjois-Pasila' 'Kluuvi' 'Lintuvaara' 'Suutarila'
#  'Pihlajamäki' 'Käpylä/Koskela' 'Lassila/ Pohjois-Haaga' 'Kivenlahti'
#  'Kontula' 'Nissas' 'Ilola' 'Torkkelinmäki' 'Puu-Vallila' 'Sompasaari'
#  'Lehtisaari' 'Ruskeasanta' 'Metsola' 'Suvela' 'Koivuhaka' 'Muurala'
#  'Itä-Pasila' 'Rekolanmäki' 'Kurkimäki' 'Vesirattaanmäki' 'Kallahti'
#  'Ala-Tikkurila' 'Perkkaa' 'Alppikylä' 'Jätkäsaari' 'Helsinki'
#  'Tikkurila/Viertola' 'Mikkelä' 'Koivukylä' 'Niittymaa / Tapiola'
#  'Gumböle' 'Laajasalo Hevossalmi' 'Hakkila' 'Olari / Puolarmetsä'
#  'Olari/Puolarmetsä' 'Tankovainio' 'Puustellinmäki' 'Länsi-Pakila'
#  'Torpparinmäki' 'Korso' 'Laajasalo /Yliskylä' 'Kivihaka' 'Niemenmäki'
#  'Uusmäki' 'Viikin latokartano' 'Katajanokka' 'Ramsinranta' 'Savela'
#  'Laaksolahti' 'Mellunmäki' 'Kulomäki (Korso)' 'Jokiniemi' 'Keimola'
#  'Sepänkylä' 'Kallio / Harju' 'Perusmäki' 'Postipuisto' 'Mäkkylä'
#  'Sepänmäki/Malmi' 'Puolarmetsä' 'Vanttila' 'Torkkelinmäki/Kallio'
#  'Karakallio' 'Linjat' 'Itä-pasila' 'Töyrynummi' 'Verkkosaari' 'Mynttilä'
#  'Rajakylä' 'Leppävaara / Perkkaa' 'Matinkylä / Tiistilä' 'Vaarala'
#  'Järvenperä; Lippajärvi; Bemböle' 'Saunalahti/Kummelivuori'
#  'Maarinkunnas' 'Suna' 'Veräjämäki' 'Simonkallio' 'Henttaanlaakso'
#  'Ymmersta' 'Eestinlaakso' 'Hämevaara' 'Matinkylä / Olari' 'Kivikko'
#  'Saarniraivio' 'Arabia' 'Espoon Keskus' 'Ylä-Malmi' 'Latokaski'
#  'Siltasaari' 'Puistola' 'Mikkola' 'Vesala' 'Keimolanmäki' 'SImonkylä'
#  'Kallio/ Torkkelinmäki' 'Kaartinkaupunki' 'Askisto' 'Mankkaa'
#  'Itä-Hakkila' 'Meri-Rastila' 'Piispankylä / Olari / Matinkylä' 'Toukola'
#  'Leppäkorpi' 'Patola' 'Nipperi' 'Konepaja/Alppiharju' 'tapiola'
#  'Olari / Henttaa' 'Pakkala / Pakkalanrinne' 'Viikinranta' 'Itä-Helsinki'
#  'Kisakylä' 'Kaskela' 'Koukkuniemi' 'Maarukka' 'Hakuninmaa'
#  'Ruoholahti/Jätkäsaari' 'Ruskesanta' 'Reimarla' 'Lassila/Pohjois-Haaga'
#  'Patola / Oulunkylä' 'Puotinharju / Puotila' 'Tikkurila city'
#  'Olari/ Puolarmetsä' 'Kivistö Keimola' 'Tammisalo']
# Unique values of district: [112  34 251 226 236  55 167 237 255 181 149 170  22  13 262  69  70 268
#   60 228 145 182   4  46 259 209   6  59  30 272 147 168  90  26  62  33
#  227 191  15 273 234 108 159 180 270  16 184 278 153 125  24   9 134 130
#   98 133 219 202 122 188 187  93 221  51  89 135 276 240 241 166 274 190
#  235 144  19 233 110  81 143 250 114   1  53  75  31  65 107  80 205  28
#   92  88   8 196 231  58 117  66  96 198   2  44 178 164 165 267  10  36
#  223  49  86  35 152 218  14 176 158 136 128 254 119 129  17  32 275  85
#  247 215 179 248 263 118 192 155 256  20  52 105 213  25 257 243 139  94
#  126 260 102 120  38 229 183  77 116 224 175  97 103  72  83 157  39 242
#  194 220 109 204 140 225  78 146  42 201  95 266  54   0 173   3  48  27
#  239 141  79 154  18 100  21 161 163 232 195 121 245  84  99  73 151 252
#  269  64 199 211 101 137  91  45  67 212  56 174 185 150 214 189 258 244
#   61 115  43 249 261 148 197 113 132 253  47 210 123 222 264 217  29 279
#   11  37 131  74 208   5  12 277 106 216 186 142 265  68 207  57  50   7
#  127  40 138 177 246 111 171 156  82 280 160 169 271  41  71  63  87 124
#   23 203 206 200 104 172 193 238 162  76 230]

# %%
display(df.head())

display(df.info())

percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percentage_missing': percent_missing})
missing_value_df.sort_values('percentage_missing', inplace=True)
missing_value_df = missing_value_df.reset_index(drop=True)

display(missing_value_df)
# Out:
#    Paivamaara  Kohdenumero Kaupunki  Kaupunginosa  \
# 0  2023-03-02   70063685.0        2           112
# 1  2023-03-02   20989644.0        3            34
# 2  2023-03-02   21125550.0        3           251
# 3  2023-03-02      67815.0        3           226
# 4  2023-03-02   70063245.0        2           236
#
#                                 Osoite Kunto Asumistyyppi  Uudiskohde  \
# 0  Kivenhakkaajankuja 3 A, 02650 Espoo     3      Omistus         0.0
# 1     Hiihtomäentie 36, 00800 Helsinki     3      Omistus         0.0
# 2     Laivurinkatu 7 A, 00150 Helsinki     3      Omistus         0.0
# 3   Suvilahdenkatu 1 A, 00500 Helsinki     2      Omistus         0.0
# 4         Jousenkaari 9 B, 02120 Espoo     3      Omistus         0.0
#
#    Tontin_omistus  Vuokratontin_lunastusosuus  ...  Ranta  Rakennusvuosi  \
# 0             3.0                         0.0  ...      0         1995.0
# 1             1.0                         0.0  ...      0         1956.0
# 2             3.0                         0.0  ...      0         1906.0
# 3             3.0                         0.0  ...      0         1961.0
# 4             3.0                         0.0  ...      0         1959.0
#
#    Energialuokka  Huoneistojen_lukumaara  Tulevat_remontit  Tehdyt_remontit  \
# 0            NaN                    63.0                 1                1
# 1            5.0                    26.0                 0                0
# 2            7.0                    22.0                 1                1
# 3            NaN                     NaN                 0                0
# 4            NaN                    84.0                 1                1
#
#     Latitude  Longitude           Coordinates TravelTime
# 0  60.222933  24.809138  60.222933, 24.809138       25.0
# 1  60.203741  25.032671  60.203741, 25.032671       24.0
# 2  60.155891  24.942462  60.155891, 24.942462       15.0
# 3  60.186996  24.966805  60.186996, 24.966805       16.0
# 4  60.175354  24.788641  60.175354, 24.788641       29.0
#
# [5 rows x 31 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3133 entries, 0 to 3238
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Paivamaara                  3133 non-null   object
#  1   Kohdenumero                 2703 non-null   float64
#  2   Kaupunki                    3133 non-null   object
#  3   Kaupunginosa                3133 non-null   int64
#  4   Osoite                      3133 non-null   object
#  5   Kunto                       3097 non-null   object
#  6   Asumistyyppi                3133 non-null   object
#  7   Uudiskohde                  3013 non-null   float64
#  8   Tontin_omistus              3052 non-null   float64
#  9   Vuokratontin_lunastusosuus  3084 non-null   float64
#  10  Velaton_hinta               3133 non-null   float64
#  11  Yhtiovastike                3133 non-null   float64
#  12  Hoitovastike                3133 non-null   float64
#  13  Rahoitusvastike             3133 non-null   float64
#  14  Tontin_vuokravastike        3133 non-null   float64
#  15  Asuinpinta_ala              3133 non-null   float64
#  16  Huoneita                    3133 non-null   float64
#  17  Kerros                      3094 non-null   float64
#  18  Korkein_kerros              3133 non-null   float64
#  19  Parveke                     3133 non-null   object
#  20  Sauna                       3133 non-null   object
#  21  Ranta                       3133 non-null   object
#  22  Rakennusvuosi               3007 non-null   float64
#  23  Energialuokka               2094 non-null   float64
#  24  Huoneistojen_lukumaara      2562 non-null   float64
#  25  Tulevat_remontit            3133 non-null   int64
#  26  Tehdyt_remontit             3133 non-null   int64
#  27  Latitude                    3133 non-null   float64
#  28  Longitude                   3133 non-null   float64
#  29  Coordinates                 3133 non-null   object
#  30  TravelTime                  3133 non-null   float64
# dtypes: float64(19), int64(3), object(9)
# memory usage: 783.2+ KB
# None
#                    column_name  percentage_missing
# 0                   Paivamaara            0.000000
# 1                    Longitude            0.000000
# 2                     Latitude            0.000000
# 3              Tehdyt_remontit            0.000000
# 4             Tulevat_remontit            0.000000
# 5                        Ranta            0.000000
# 6                        Sauna            0.000000
# 7                      Parveke            0.000000
# 8               Korkein_kerros            0.000000
# 9                     Huoneita            0.000000
# 10                 Coordinates            0.000000
# 11        Tontin_vuokravastike            0.000000
# 12             Rahoitusvastike            0.000000
# 13              Asuinpinta_ala            0.000000
# 14                Yhtiovastike            0.000000
# 15                    Kaupunki            0.000000
# 16                Kaupunginosa            0.000000
# 17                      Osoite            0.000000
# 18                Hoitovastike            0.000000
# 19                Asumistyyppi            0.000000
# 20                  TravelTime            0.000000
# 21               Velaton_hinta            0.000000
# 22                       Kunto            1.149058
# 23                      Kerros            1.244813
# 24  Vuokratontin_lunastusosuus            1.563996
# 25              Tontin_omistus            2.585381
# 26                  Uudiskohde            3.830195
# 27               Rakennusvuosi            4.021704
# 28                 Kohdenumero           13.724864
# 29      Huoneistojen_lukumaara           18.225343
# 30               Energialuokka           33.163102

# %%
final_df = pd.DataFrame()

final_df['date']                      = df['Paivamaara']
final_df['id']                        = df['Kohdenumero']
final_df['city']                      = df['Kaupunki']
final_df['district']                  = df['Kaupunginosa']
final_df['address']                   = df['Osoite']
final_df['coordinates']               = df['Coordinates']
final_df['travel_time']               = df['TravelTime']
final_df['condition']                 = df['Kunto']
final_df['new_building']              = df['Uudiskohde']
final_df['price']                     = df['Velaton_hinta']
final_df['condominium_fee']           = df['Yhtiovastike']
final_df['condominium_operation_fee'] = df['Hoitovastike']
final_df['condominium_financial_fee'] = df['Rahoitusvastike']
final_df['condominium_land_rent_fee'] = df['Tontin_vuokravastike']
final_df['area']                      = df['Asuinpinta_ala']
final_df['rooms']                     = df['Huoneita']
final_df['floor']                     = df['Kerros']
final_df['top_floor']                 = df['Korkein_kerros']
final_df['balcony']                   = df['Parveke']
final_df['sauna']                     = df['Sauna']
final_df['beach']                     = df['Ranta']
final_df['building_year']             = df['Rakennusvuosi']
final_df['apartments_in_building']    = df['Huoneistojen_lukumaara']
final_df['lvi_upcoming']              = df['Tulevat_remontit']
final_df['lvi_past']                  = df['Tehdyt_remontit']




final_df.to_csv('processed_housing_data.csv', index=False)
